# %%
# data generator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# 1. Generate the dataset
X, y = make_classification(
    n_samples=500,       # Number of rows
    n_features=2,        # 2D for easy visualization
    n_redundant=0, 
    n_clusters_per_class=1, 
    class_sep=1.5,       # Higher = easier to separate
    random_state=41
)

# 2. Convert to a DataFrame for readability
df = pd.DataFrame(X, columns=['X', 'Y'])
df['Label'] = y


print(df.head())
# Out:
#           X         Y  Label
# 0 -1.385229  3.248389      0
# 1 -3.216804  1.298221      0
# 2 -1.845291  4.004962      0
# 3 -0.084972  1.873154      0
# 4  2.232860 -0.884339      1

# %%
#visualize
import matplotlib.pyplot as plt

# Create the figure
plt.figure(figsize=(10, 6))

# Loop through each unique label (0 and 1)
for label in df['Label'].unique():
    # Filter the dataframe for the current label
    subset = df[df['Label'] == label]
    
    # Plot the points
    plt.scatter(
        subset['X'], 
        subset['Y'], 
        label=f'Class {label}',
        alpha=0.7,      # Transparency to see overlap
        edgecolors='k'  # Black border around points
    )

# Formatting the plot
plt.title("Synthetic Dataset for k-NN Classification")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
import math
X = df["X"]
Y = df['Y']
l = df['Label']
dist = dict()
k = 5

# %%
dx , dy = 0.33, 0.2

# %%
for i in range(len(X)):
    d = math.sqrt((X[i] - dx) ** 2 + (Y[i] - dy) ** 2)
    dist[d] = l[i]

# %%
sort_d = sorted(dist.items())

# %%
first_k = list(sort_d)[:k]

# %%
first_k
# Out:
# [(0.3433679908231883, np.int64(1)),
#  (0.36034631133307826, np.int64(1)),
#  (0.4423721566730479, np.int64(1)),
#  (0.44892387253503496, np.int64(0)),
#  (0.49609829128252286, np.int64(0))]

# %%
fl = 0
c0 = 0
c1 = 0
for i in range(len(first_k)):
    label = int(first_k[i][1])
    if label == 1:
        c1 += 1
    else: 
        c0 += 1

if c1>c0:
    fl = 1

# %%
fl
# Out:
# 1

# %%
#visualize
import matplotlib.pyplot as plt

# Create the figure
plt.figure(figsize=(10, 6))

# Loop through each unique label (0 and 1)
for label in df['Label'].unique():
    # Filter the dataframe for the current label
    subset = df[df['Label'] == label]
    
    # Plot the points
    plt.scatter(
        subset['X'], 
        subset['Y'], 
        label=f'Class {label}',
        alpha=0.7,      # Transparency to see overlap
        edgecolors='k'  # Black border around points
    )

plt.scatter( dx, dy, edgecolors='k')
# Formatting the plot
plt.title("Synthetic Dataset for k-NN Classification")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
